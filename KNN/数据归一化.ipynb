# %% [markdown]
# ## 数据归一化处理

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 最值归一化 Normalization

# %%
x = np.random.randint(0,100,size=100)
x
# Out:
# array([92, 74, 26, 61, 56, 39, 70, 23, 62, 25, 13, 79, 68, 89, 31, 91, 60,
#         3, 42, 83, 21, 78, 87, 51, 57, 75, 33, 72, 41, 26, 77, 60, 70, 77,
#         7, 36, 42, 89, 84, 64, 99, 82, 84, 55, 14, 24, 71, 30, 49, 88, 33,
#        69, 11, 38, 78, 30, 87,  3, 91, 29, 61, 43, 55, 72,  1, 34, 42, 25,
#        65, 43, 32, 89, 93, 33,  0, 79, 60, 94,  9,  8, 92, 70, 47, 59,  8,
#        30, 68, 49, 20, 87,  5, 11, 55, 62, 51, 58, 81, 68, 62, 28])

# %%
(x - np.min(x)) / (np.max(x) - np.min(x))
# Out:
# array([0.92929293, 0.74747475, 0.26262626, 0.61616162, 0.56565657,
#        0.39393939, 0.70707071, 0.23232323, 0.62626263, 0.25252525,
#        0.13131313, 0.7979798 , 0.68686869, 0.8989899 , 0.31313131,
#        0.91919192, 0.60606061, 0.03030303, 0.42424242, 0.83838384,
#        0.21212121, 0.78787879, 0.87878788, 0.51515152, 0.57575758,
#        0.75757576, 0.33333333, 0.72727273, 0.41414141, 0.26262626,
#        0.77777778, 0.60606061, 0.70707071, 0.77777778, 0.07070707,
#        0.36363636, 0.42424242, 0.8989899 , 0.84848485, 0.64646465,
#        1.        , 0.82828283, 0.84848485, 0.55555556, 0.14141414,
#        0.24242424, 0.71717172, 0.3030303 , 0.49494949, 0.88888889,
#        0.33333333, 0.6969697 , 0.11111111, 0.38383838, 0.78787879,
#        0.3030303 , 0.87878788, 0.03030303, 0.91919192, 0.29292929,
#        0.61616162, 0.43434343, 0.55555556, 0.72727273, 0.01010101,
#        0.34343434, 0.42424242, 0.25252525, 0.65656566, 0.43434343,
#        0.32323232, 0.8989899 , 0.93939394, 0.33333333, 0.        ,
#        0.7979798 , 0.60606061, 0.94949495, 0.09090909, 0.08080808,
#        0.92929293, 0.70707071, 0.47474747, 0.5959596 , 0.08080808,
#        0.3030303 , 0.68686869, 0.49494949, 0.2020202 , 0.87878788,
#        0.05050505, 0.11111111, 0.55555556, 0.62626263, 0.51515152,
#        0.58585859, 0.81818182, 0.68686869, 0.62626263, 0.28282828])

# %%
X = np.random.randint(0,100,(50,2))
X[:10,:]
# Out:
# array([[34, 39],
#        [38, 61],
#        [90, 23],
#        [24, 78],
#        [68, 67],
#        [83, 47],
#        [64, 64],
#        [97, 30],
#        [63, 40],
#        [70, 96]])

# %%
X = np.array(X,dtype = float)
X[:10,:]
# Out:
# array([[34., 39.],
#        [38., 61.],
#        [90., 23.],
#        [24., 78.],
#        [68., 67.],
#        [83., 47.],
#        [64., 64.],
#        [97., 30.],
#        [63., 40.],
#        [70., 96.]])

# %%
X[:,0] = (X[:,0] - np.min(X[:,0])) / (np.max(X[:,0]) - np.min(X[:,0]))
X[:,1] = (X[:,1] - np.min(X[:,1])) / (np.max(X[:,1]) - np.min(X[:,1]))

# %%
X[:10,:]
# Out:
# array([[0.34020619, 0.38709677],
#        [0.3814433 , 0.62365591],
#        [0.91752577, 0.21505376],
#        [0.2371134 , 0.80645161],
#        [0.69072165, 0.68817204],
#        [0.84536082, 0.47311828],
#        [0.64948454, 0.65591398],
#        [0.98969072, 0.29032258],
#        [0.63917526, 0.39784946],
#        [0.71134021, 1.        ]])

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
np.mean(X[:,0])
# Out:
# 0.4783505154639176

# %%
np.std(X[:,0])
# Out:
# 0.2949678932181368

# %%
np.mean(X[:,1])
# Out:
# 0.48086021505376353

# %%
np.std(X[:,1])
# Out:
# 0.3118504997413401

# %% [markdown]
# ### 均值方差归一化 Standardization

# %%
X2 = np.random.randint(0,100,(50,2))

# %%
X2 = np.array(X2,dtype=float)

# %%
X2[:,0] = (X2[:,0] - np.mean(X2[:,0])) / np.std(X2[:,0])
X2[:,1] = (X2[:,1] - np.mean(X2[:,1])) / np.std(X2[:,1])

# %%
plt.scatter(X2[:,0],X2[:,1])
plt.show()

# %%
np.mean(X2[:,0])
# Out:
# 7.993605777301127e-17

# %%
np.std(X2[:,0])
# Out:
# 1.0

# %%
np.mean(X2[:,1])
# Out:
# 3.3306690738754695e-18

# %%
np.std(X2[:,1])
# Out:
# 0.9999999999999999
